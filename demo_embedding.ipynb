# %%
#pip install ollama scikit-learn
#pip install tiktoken
##pip install langchain-community

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import os
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
query = "what is a transformer network"

chunk1 = "The Transformer architecture is a neural network model, primarily for sequential data, that uses an encoder-decoder structure and the self-attention mechanism to process entire sequences at once, capturing context and relationships between all parts of the data. This differs from older models like RNNs which process data sequentially. The encoder processes the input into contextual embeddings, which are then used by the decoder to generate the output sequence, often word by word"

chunk2 = "Transformer is a series of science fiction action films based on the Transformers franchise. Michael Bay directed the first five live action films: Transformers, Revenge of the Fallen, Dark of the Moon, Age of Extinction, and The Last Knight, and has served as a producer for subsequent films."

EMBED_MODEL = "text-embedding-3-small"
print(f"[INFO] Using OpenAI Embeddings: {EMBED_MODEL}")
embedding_model = OpenAIEmbeddings(model=EMBED_MODEL)

response= embedding_model.embed_query(query)
response1 = embedding_model.embed_query(chunk1)
response2 = embedding_model.embed_query(chunk2)
# Out:
# [INFO] Using OpenAI Embeddings: text-embedding-3-small

# %%
print(response)
print(response1)
print(response2)
# Out:
# [-0.03246286138892174, -0.0021341207902878523, -0.04625893756747246, -0.05482729896903038, 0.018794286996126175, -0.009913540445268154, 0.03146831691265106, 0.038787126541137695, -0.04827352240681648, 0.03582900017499924, 0.008281472139060497, -0.01750648394227028, 0.003646652912721038, -0.00881061889231205, 0.004539190325886011, -0.004803763702511787, 0.05334823578596115, -0.014216845855116844, 0.03970516473054886, 0.028102178126573563, -0.027745163068175316, 0.02659761533141136, 0.031111303716897964, 0.025666825473308563, -0.03756307438015938, 0.017264222726225853, -0.0019699574913829565, 0.03440093994140625, 0.022912710905075073, -0.0229764636605978, 0.023715993389487267, -0.03182533383369446, -0.05263420566916466, 0.0027190514374524355, 0.03822610154747963, -0.0005594296962954104, 0.01808025687932968, 0.03381441533565521, 0.0047081345692276955, 0.05671437829732895, 0.010704073123633862, -0.009741407819092274, -0.01941906288266182, 0.027464650571346283, 0.013898082077503204, -0.02
# ...

# %%
# Convert it into array ( sequence of numbers )
embed1 = np.array(response).reshape(1, -1)
embed2 = np.array(response1).reshape(1, -1)
embed3 = np.array(response2).reshape(1, -1)

print(cosine_similarity(embed1,embed2))
print(cosine_similarity(embed1,embed3))
# Out:
# [[0.54929001]]
# [[0.47854531]]
